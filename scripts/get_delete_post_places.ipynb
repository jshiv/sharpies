# %%
import urltoys
urltoys.local = True
ip = urltoys.get_public_ip()

# %%
urltoys.make_url( ip = ip)
# Out:
# u'http://198.135.48.141:8080/api/v1.0/places'

# %% [markdown]
# # Get the data

# %%
data = urltoys.get_dict(urltoys.make_url(ip = ip))
data
# Out:
# {u'places': [{u'_id': u'54f230acd1e26e2d3dfbf1d9',
#    u'address': u'43 Central Ave',
#    u'cover': 20,
#    u'hours': None,
#    u'image': u'BartinisBarImage',
#    u'information': u'$1 Jello Shots all night!!!',
#    u'lat': u'37.788359',
#    u'line': 0,
#    u'long': u'-122.424324',
#    u'name': u'Bartinis',
#    u'phone': u'978-319-1460',
#    u'pop': 5,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Dive/Sports Bar',
#    u'uri': u'/api/v1.0/places/54f230acd1e26e2d3dfbf1d9'},
#   {u'_id': u'54f230acd1e26e2d3dfbf1da',
#    u'address': u'1500 white terrace',
#    u'cover': 0,
#    u'hours': None,
#    u'image': u'RootsBarImage',
#    u'information': u'Roots Bar is a contemporary venue that has a wide selection of drinks from around the world.',
#    u'lat': u'37.786121',
#    u'line': 0,
#    u'long': u'-122.413294',
#    u'name': u'Roots Bar',
#    u'phone': u'978-319-1460',
#    u'pop': 1,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/54f230acd1e26e2d3dfbf1da'},
#   {u'_id': u'54f230acd1e26e2d3dfbf1db',
#    u'address': u'30 Alexander Ave',
#    u'cover': 15,
#    u'hours': None,
#    u'image': u'BluBarImage',
#    u'information': u'Club Blu has a newly renovated dance floor with new and improved lighting',
#    u'lat': u'37.781542',
#    u'line': 0,
#    u'long': u'-122.408016',
#    u'name': u'Club Blu',
#    u'phone': u'978-319-1460',
#    u'pop': 2,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/54f230acd1e26e2d3dfbf1db'},
#   {u'_id': u'54f230acd1e26e2d3dfbf1dc',
#    u'address': u'Francois Street',
#    u'cover': 25,
#    u'hours': None,
#    u'image': u'ParisBarImage',
#    u'information': u'Top shelf drinks $3 all night',
#    u'lat': u'37.787477',
#    u'line': 0,
#    u'long': u'-122.409003',
#    u'name': u'Paris Lounge',
#    u'phone': u'978-319-1460',
#    u'pop': 3,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/54f230acd1e26e2d3dfbf1dc'},
#   {u'_id': u'54f230acd1e26e2d3dfbf1dd',
#    u'address': u'111 No idea street',
#    u'cover': 0,
#    u'hours': None,
#    u'image': u'No image available',
#    u'information': u'Like we know!!!',
#    u'lat': u'37.792700',
#    u'line': 0,
#    u'long': u'-122.438700',
#    u'name': u'The Spot',
#    u'phone': u'978-319-1460',
#    u'pop': 5,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Unknown',
#    u'uri': u'/api/v1.0/places/54f230acd1e26e2d3dfbf1dd'}]}

# %% [markdown]
# # Get the id's

# %%
id_list = [item['_id'] for item in data['places']]
id_list
# Out:
# [u'54f230acd1e26e2d3dfbf1d9',
#  u'54f230acd1e26e2d3dfbf1da',
#  u'54f230acd1e26e2d3dfbf1db',
#  u'54f230acd1e26e2d3dfbf1dc',
#  u'54f230acd1e26e2d3dfbf1dd']

# %% [markdown]
# # delete the data

# %%
for i in id_list:
    urltoys.delete(urltoys.make_url(url_ext='places/'+i, ip = ip))

# %% [markdown]
# # Hard coded dataset

# %%
s = [{u'address': u'43 Central Ave',
  u'cover': 20,
  u'image': u'BartinisBarImage',
  u'information': u'$1 Jello Shots all night!!!',
  u'lat': u'37.788359',
  u'long': u'-122.424324',
  u'name': u'Bartinis',
  u'phone': u'978-319-1460',
  u'pop': 5,
  u'type': u'Dive/Sports Bar'},
 {u'address': u'1500 white terrace',
  u'cover': 0,
  u'image': u'RootsBarImage',
  u'information': u'Roots Bar is a contemporary venue that has a wide selection of drinks from around the world.',
  u'lat': u'37.786121',
  u'long': u'-122.413294',
  u'name': u'Roots Bar',
  u'phone': u'978-319-1460',
  u'pop': 1,
  u'type': u'Night Club'},
 {u'address': u'30 Alexander Ave',
  u'cover': 15,
  u'image': u'BluBarImage',
  u'information': u'Club Blu has a newly renovated dance floor with new and improved lighting',
  u'lat': u'37.781542',
  u'long': u'-122.408016',
  u'name': u'Club Blu',
  u'phone': u'978-319-1460',
  u'pop': 2,
  u'type': u'Night Club'},
 {u'address': u'Francois Street',
  u'cover': 25,
  u'image': u'ParisBarImage',
  u'information': u'Top shelf drinks $3 all night',
  u'lat': u'37.787477',
  u'long': u'-122.409003',
  u'name': u'Paris Lounge',
  u'phone': u'978-319-1460',
  u'pop': 3,
  u'type': u'Night Club'},
 {u'address': u'111 No idea street',
  u'cover': 0,
  u'image': u'No image available',
  u'information': u'Like we know!!!',
  u'lat': u'37.792700',
  u'long': u'-122.438700',
  u'name': u'The Spot',
  u'phone': u'978-319-1460',
  u'pop': 5,
  u'type': u'Unknown'}]

# %%
import json
with open('./data/places.json', 'r') as f:
    s = json.load(f)

# %%
s
# Out:
# [{u'address': u'2801 Leavenworth Street, San Francisco, CA 94133, USA',
#   u'hours': u'4:00pm-8:00am',
#   u'image': u'http://www.theparlorsf.com/media/uploads/interior_pics/front_door_homepage_horizontal.jpg',
#   u'lat': u'37.8073431',
#   u'long': u'-122.4194274',
#   u'name': u'The Parlor',
#   u'phone': u'(415) 775-5110',
#   u'type': u'Lounge Bar And Night Club'},
#  {u'address': u'540 Clement Street, San Francisco, CA 94118, USA',
#   u'hours': u'12:00pm-2:00am',
#   u'image': u'http://thenoisebeneaththeapple.com/wp-content/uploads/2012/08/540-club.jpg',
#   u'lat': u'37.7830929',
#   u'long': u'-122.4651637',
#   u'name': u'540 Club',
#   u'phone': u'(415) 752-7276',
#   u'type': u'Bar'},
#  {u'address': u'500 Guerrero Street, San Francisco, CA 94110, USA',
#   u'hours': u'11:00 am - 2:00 am',
#   u'image': u'http://500clubsf.com/yahoo_site_admin/assets/images/5sign.78232104_std.jpg',
#   u'lat': u'37.7630363',
#   u'long': u'-122.4241888',
#   u'name': u'The 500 Club',
#   u'phone': u'(415) 861-2500',
#   u'type': u'Bar'},
#  {u'address': u'1160 Polk Street, San Francisco, CA 94109, USA',
#   u'hours': u'3:00 pm - 2:00 am',
#   u'image': u'https://cbks3.google.com/cbk?output=thumbnail&cb_client=maps_sv&thumb=2&panoid=YQxqYBXmPZaYHAK_HWg49w&yaw=334.6064863861733&w=333&h=79',
#   u'lat': u'37.7875296',
#   u'long': u'-122.419814',
#   u'name': u'Vertigo',
#   u'phone': u'(415) 674-1278',
#   u'type': u'Bar'},
#  {u'address': u'3286 22nd Street, San Francisco, CA 94110, USA',
#   u'hours': u'5:00 pm---2:00 am',
#   u'image': u'https://s-media-cache-ak0.pinimg.com/originals/7d/9d/1e/7d9d1ec887289c49d1c536340c33b4e9.jpg',
#   u'lat': u'37.7553415',
#   u'long': u'-122.4206599',
#   u'name': u'Latin American Club',
#   u'phone': u'(415) 647-2732',
#   u'type': u'Bar'},
#  {u'address': u'4121 18th Street, San Francisco, CA 94114, USA',
#   u'hours': u'-3:00 pm - 2:00 am',
#   u'image': u'http://s3-media2.fl.yelpcdn.com/bphoto/rCjnajLYPAQfsC-4SZ5LBA/l.jpg',
#   u'lat': u'37.7607493',
#   u'long': u'-122.4354615',
#   u'name': u'San Francisco Badlands',
#   u'phone': u'(415) 626-9320',
#   u'type': u'Night Club'},
#  {u'address': u'1192 Folsom Street, San Francisco, CA 94103, USA',
#   u'hours': u'5:00 pm - 3:00 am',
#   u'image': u'https://lh3.googleusercontent.com/-v2LRG0dy-gE/VNVl8sPHTPI/AAAAAAAAABE/etCksJeJYnE/s242-k-no/photo.jpg',
#   u'lat': u'37.775307',
#   u'long': u'-122.4099488',
#   u'name': u'F8',
#   u'phone': u'(415) 857-1192',
#   u'type': u'Lounge'},
#  {u'address': u'20 Yerba Buena Lane, San Francisco, CA 94130, USA',
#   u'hours': u'2:00 pm - 12:00 am',
#   u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=uRz9MR8A2rYAAAQY7sOC2A&x=0&y=0&zoom=5',
#   u'lat': u'37.7859785',
#   u'long': u'-122.4045719',
#   u'name': u'Press Club',
#   u'phone': u'(415) 744-5000',
#   u'type': u'Wine Bar'},
#  {u'address': u'3138 Fillmore Street, San Francisco, CA 94123, USA',
#   u'hours': u'10pm-2am',
#   u'image': u'http://www.matrixfillmore.com/images/home_image_3.jpg',
#   u'lat': u'37.7986879',
#   u'long': u'-122.435665',
#   u'name': u'MatrixFillmore',
#   u'phone': u'(415) 563-4180',
#   u'type': u'Night Club'},
#  {u'address': u'3225 22nd Street, San Francisco, CA 94110, USA',
#   u'hours': u'6pm-2am',
#   u'image': u'http://danivox.com/wp-content/uploads/2012/12/DaniVox_MOR_8.jpg',
#   u'lat': u'37.7552647',
#   u'long': u'-122.4193588',
#   u'name': u'Make-Out Room',
#   u'phone': u'(415) 647-2888',
#   u'type': u'Night Club'},
#  {u'address': u'1015 Folsom Street, San Francisco, CA 94103, USA',
#   u'hours': u' 10:00 pm - 3:00 am',
#   u'image': u'http://guestlistspy.com/wp-content/uploads/2012/07/1015-folsom-guestlist.jpg',
#   u'lat': u'37.7781009',
#   u'long': u'-122.4057628',
#   u'name': u'1015 Folsom',
#   u'phone': u'(415) 431-1200',
#   u'type': u'Night Club'},
#  {u'address': u'420 Mason Street, San Francisco, CA 94102, USA',
#   u'hours': u'9pm-2am',
#   u'image': u'http://www.rubyskye.com/_images/RubySkye.jpg',
#   u'lat': u'37.7875918',
#   u'long': u'-122.4098052',
#   u'name': u'Ruby Skye',
#   u'phone': u'(415) 693-0777',
#   u'type': u'Night Club'},
#  {u'address': u'853 Valencia Street, San Francisco, CA 94110, USA',
#   u'hours': u'5:00 pm - 2:00 am',
#   u'image': u'http://uplup.com/music_spot/amnesia-san-francisco/additional_images/Amnesia%20bar.jpg',
#   u'lat': u'37.759309',
#   u'long': u'-122.4210613',
#   u'name': u'Amnesia',
#   u'phone': u'(415) 970-0012',
#   u'type': u'Bar'},
#  {u'address': u'401 6th Street, San Francisco, CA 94103, USA',
#   u'hours': u' \nFriday 9:30 pm - 8:00 am\nSaturday 10:00 pm - 8:00 am\nSunday 1:00 - 9:00 pm \n',
#   u'image': u'http://www.theendup.com/club/wp-content/uploads/galleryimages/b7g76jET95e1icT8.jpg',
#   u'lat': u'37.7772436',
#   u'long': u'-122.4037707',
#   u'name': u'The Endup',
#   u'phone': u'(415) 646-0999',
#   u'type': u'Bar'},
#  {u'address': u'43 6th Street, San Francisco, CA 94103, USA',
#   u'hours': u'7:00 pm - 2:00 am ',
#   u'image': u'https://evbdn.eventbrite.com/s3-s3/eventlogos/32513655/image2.png',
#   u'lat': u'37.7818047',
#   u'long': u'-122.4093351',
#   u'name': u'OMG!',
#   u'phone': u'(415) 896-6473',
#   u'type': u'Night Club'},
#  {u'address': u'375 11th Street, San Francisco, CA 94103, USA',
#   u'hours': u'Open 24 hours',
#   u'image': u'https://www.dnalounge.com/booking/005.jpg',
#   u'lat': u'37.7710189',
#   u'long': u'-122.412719',
#   u'name': u'DNA Lounge',
#   u'phone': u'(415) 626-1409',
#   u'type': u'Night Club'},
#  {u'address': u'124 Ellis Street, San Francisco, CA 94102, USA',
#   u'hours': u'6:00 pm - 2:00 am',
#   u'image': u'http://guestlistamerica.com/wp-content/uploads/2013/02/main-lounge.jpg',
#   u'lat': u'37.7856002',
#   u'long': u'-122.4085226',
#   u'name': u'Infusion Lounge',
#   u'phone': u'(415) 421-8700',
#   u'type': u'Lounge'},
#  {u'address': u'540 Howard Street, San Francisco, CA 94105, USA',
#   u'hours': u'10:00 pm - 4:00 am',
#   u'image': u'http://photos3.meetupstatic.com/photos/event/a/4/0/8/600_430061992.jpeg',
#   u'lat': u'37.7879165',
#   u'long': u'-122.3972358',
#   u'name': u'Temple Nightclub',
#   u'phone': u'(415) 978-9942',
#   u'type': u'Night Club'},
#  {u'address': u'46 Minna Street, San Francisco, CA 94105, USA',
#   u'hours': u'9:00 pm - 2:00 am',
#   u'image': u'http://cdn.djoybeat.com/wp-content/uploads/2012/12/harlot-sf3.jpg',
#   u'lat': u'37.7885627',
#   u'long': u'-122.3982112',
#   u'name': u'Harlot',
#   u'phone': u'(415) 777-1077',
#   u'type': u'Night Club'},
#  {u'address': u'3600 16th Street, San Francisco, CA 94114, USA',
#   u'hours': u'3:30 pm - 2:00 am',
#   u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=_bLCsw6PBLIAAAQfCRPoLQ&x=0&y=0&zoom=5',
#   u'lat': u'37.7643965',
#   u'long': u'-122.4334227',
#   u'name': u'Lookout',
#   u'phone': u'(415) 431-0306',
#   u'type': u'Gay Bar'},
#  {u'address': u'824 Ulloa Street, San Francisco, CA 94127, USA',
#   u'hours': u'10:00 am - 2:00 am',
#   u'image': u'https://lh3.googleusercontent.com/-8BbNqkpbUCE/Ug0zsuiPk6I/AAAAAAAALMM/VrQeyHnRlBk/s285-k-no/2013-08-15',
#   u'lat': u'37.7408498',
#   u'long': u'-122.4654431',
#   u'name': u'Philosophers Club',
#   u'phone': u'(415) 753-0599',
#   u'type': u'Bar'},
#  {u'address': u'201 9th Street, San Francisco, CA 94103, USA',
#   u'hours': u'7:15 pm - 2:00 am',
#   u'image': u'http://asiasf.com/wp-content/uploads/2013/08/aliyah-amber-nya.jpg',
#   u'lat': u'37.7750644',
#   u'long': u'-122.4127649',
#   u'name': u'AsiaSF',
#   u'phone': u'(415) 255-2742',
#   u'type': u'Asian Fusion Restaurant / Nigh Club'},
#  {u'address': u'3139 16th Street, San Francisco, CA 94103, USA',
#   u'hours': u'-2:00 pm - 2:00 am',
#   u'image': u'https://lh6.googleusercontent.com/-vl37m4n-8xM/Uae7wVLdyUI/AAAAAAAAE8M/4pJRXEK7LyY/s285-k-no/2013-05-30',
#   u'lat': u'37.7648463',
#   u'long': u'-122.4228718',
#   u'name': u'Delirium',
#   u'phone': u'(415) 552-5525',
#   u'type': u'Cocktail Bar'},
#  {u'address': u'23 Visitacion Avenue, Brisbane, CA 94005, USA',
#   u'hours': u'3pm - 2 am',
#   u'image': u'https://lh6.googleusercontent.com/-gVSVS9fv0TQ/VMiSwcGk6PI/AAAAAAAAAAc/CQjSSlNB3CE/s286-k-no/photo.jpg',
#   u'lat': u'37.6841542',
#   u'long': u'-122.4024009',
#   u'name': u'23 Club',
#   u'phone': u'(415) 467-7717',
#   u'type': u'Bar'}]

# %% [markdown]
# # Post the hardcoded dataset

# %%
for data in s:
    print data
    urltoys.post_dict(urltoys.make_url(ip = ip), data )
# Out:
# {u'name': u'The Parlor', u'image': u'http://www.theparlorsf.com/media/uploads/interior_pics/front_door_homepage_horizontal.jpg', u'long': u'-122.4194274', u'hours': u'4:00pm-8:00am', u'phone': u'(415) 775-5110', u'address': u'2801 Leavenworth Street, San Francisco, CA 94133, USA', u'lat': u'37.8073431', u'type': u'Lounge Bar And Night Club'}
# {u'name': u'540 Club', u'image': u'http://thenoisebeneaththeapple.com/wp-content/uploads/2012/08/540-club.jpg', u'long': u'-122.4651637', u'hours': u'12:00pm-2:00am', u'phone': u'(415) 752-7276', u'address': u'540 Clement Street, San Francisco, CA 94118, USA', u'lat': u'37.7830929', u'type': u'Bar'}
# {u'name': u'The 500 Club', u'image': u'http://500clubsf.com/yahoo_site_admin/assets/images/5sign.78232104_std.jpg', u'long': u'-122.4241888', u'hours': u'11:00 am - 2:00 am', u'phone': u'(415) 861-2500', u'address': u'500 Guerrero Street, San Francisco, CA 94110, USA', u'lat': u'37.7630363', u'type': u'Bar'}
# {u'name': u'Vertigo', u'image': u'https://cbks3.google.com/cbk?output=thumbnail&cb_client=maps_sv&thumb=2&panoid=YQxqYBXmPZaYHAK_HWg49w&yaw=334.6064863861733&w=333&h=79', u'long': u'-122.419814', u'hours': u'3:00 pm - 2:00 am', u'phone': u'(415) 674-1278', u'address': u'1160 Polk Street, San Francisco, CA 94109, USA', u'lat': u'37.7875296', u'type': u'Bar'}
# {u'name': u'Latin American Club', u'image': u'https://s-media-cache-ak0.pinimg.com/originals/7d/9d/1e/7d9d1ec887289c49d1c536340c33b4e9.jpg', u'long': u'-122.4206599', u'hours': u'5:00 pm---2:00 am', u'phone': u'(415) 647-2732', u'address': u'3286 22nd Street, San Francisco, CA 94110, USA', u'lat': u'37.7553415', u'type': u'Bar'}
# {u'name': u'San Francisco Badlands', u'image': u'http://s3-media2.fl.yelpcdn.com/bphoto/rCjnajLYPAQfsC-4SZ5LBA/l.jpg', u'long': u'-122.4354615', u'hours': u'-3:00 pm - 2:00 am', u'phone': u'(415) 626-9320', u'address': u'4121 18th Street, San Francisco, CA 94114, USA', u'lat': u'37.7607493', u'type': u'Night Club'}
# {u'name': u'F8', u'image': u'https://lh3.googleusercontent.com/-v2LRG0dy-gE/VNVl8sPHTPI/AAAAAAAAABE/etCksJeJYnE/s242-k-no/photo.jpg', u'long': u'-122.4099488', u'hours': u'5:00 pm - 3:00 am', u'phone': u'(415) 857-1192', u'address': u'1192 Folsom Street, San Francisco, CA 94103, USA', u'lat': u'37.775307', u'type': u'Lounge'}
# {u'name': u'Press Club', u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=uRz9MR8A2rYAAAQY7sOC2A&x=0&y=0&zoom=5', u'long': u'-122.4045719', u'hours': u'2:00 pm - 12:00 am', u'phone': u'(415) 744-5000', u'address': u'20 Yerba Buena Lane, San Francisco, CA 94130, USA', u'lat': u'37.7859785', u'type': u'Wine Bar'}
# {u'name': u'MatrixFillmore', u'image': u'http://www.matrixfillmore.com/images/home_image_3.jpg', u'long': u'-122.435665', u'hours': u'10pm-2am', u'phone': u'(415) 563-4180', u'address': u'3138 Fillmore Street, San Francisco, CA 94123, USA', u'lat': u'37.7986879', u'type': u'Night Club'}
# {u'name': u'Make-Out Room', u'image': u'http://danivox.com/wp-content/uploads/2012/12/DaniVox_MOR_8.jpg', u'long': u'-122.4193588', u'hours': u'6pm-2am', u'phone': u'(415) 647-2888', u'address': u'3225 22nd Street, San Francisco, CA 94110, USA', u'lat': u'37.7552647', u'type': u'Night Club'}
# {u'name': u'1015 Folsom', u'image': u'http://guestlistspy.com/wp-content/uploads/2012/07/1015-folsom-guestlist.jpg', u'long': u'-122.4057628', u'hours': u' 10:00 pm - 3:00 am', u'phone': u'(415) 431-1200', u'address': u'1015 Folsom Street, San Francisco, CA 94103, USA', u'lat': u'37.7781009', u'type': u'Night Club'}
# {u'name': u'Ruby Skye', u'image': u'http://www.rubyskye.com/_images/RubySkye.jpg', u'long': u'-122.4098052', u'hours': u'9pm-2am', u'phone': u'(415) 693-0777', u'address': u'420 Mason Street, San Francisco, CA 94102, USA', u'lat': u'37.7875918', u'type': u'Night Club'}
# {u'name': u'Amnesia', u'image': u'http://uplup.com/music_spot/amnesia-san-francisco/additional_images/Amnesia%20bar.jpg', u'long': u'-122.4210613', u'hours': u'5:00 pm - 2:00 am', u'phone': u'(415) 970-0012', u'address': u'853 Valencia Street, San Francisco, CA 94110, USA', u'lat': u'37.759309', u'type': u'Bar'}
# {u'name': u'The Endup', u'image': u'http://www.theendup.com/club/wp-content/uploads/galleryimages/b7g76jET95e1icT8.jpg', u'long': u'-122.4037707', u'hours': u' \nFriday 9:30 pm - 8:00 am\nSaturday 10:00 pm - 8:00 am\nSunday 1:00 - 9:00 pm \n', u'phone': u'(415) 646-0999', u'address': u'401 6th Street, San Francisco, CA 94103, USA', u'lat': u'37.7772436', u'type': u'Bar'}
# {u'name': u'OMG!', u'image': u'https://evbdn.eventbrite.com/s3-s3/eventlogos/32513655/image2.png', u'long': u'-122.4093351', u'hours': u'7:00 pm - 2:00 am ', u'phone': u'(415) 896-6473', u'address': u'43 6th Street, San Francisco, CA 94103, USA', u'lat': u'37.7818047', u'type': u'Night Club'}
# {u'name': u'DNA Lounge', u'image': u'https://www.dnalounge.com/booking/005.jpg', u'long': u'-122.412719', u'hours': u'Open 24 hours', u'phone': u'(415) 626-1409', u'address': u'375 11th Street, San Francisco, CA 94103, USA', u'lat': u'37.7710189', u'type': u'Night Club'}
# {u'name': u'Infusion Lounge', u'image': u'http://guestlistamerica.com/wp-content/uploads/2013/02/main-lounge.jpg', u'long': u'-122.4085226', u'hours': u'6:00 pm - 2:00 am', u'phone': u'(415) 421-8700', u'address': u'124 Ellis Street, San Francisco, CA 94102, USA', u'lat': u'37.7856002', u'type': u'Lounge'}
# {u'name': u'Temple Nightclub', u'image': u'http://photos3.meetupstatic.com/photos/event/a/4/0/8/600_430061992.jpeg', u'long': u'-122.3972358', u'hours': u'10:00 pm - 4:00 am', u'phone': u'(415) 978-9942', u'address': u'540 Howard Street, San Francisco, CA 94105, USA', u'lat': u'37.7879165', u'type': u'Night Club'}
# {u'name': u'Harlot', u'image': u'http://cdn.djoybeat.com/wp-content/uploads/2012/12/harlot-sf3.jpg', u'long': u'-122.3982112', u'hours': u'9:00 pm - 2:00 am', u'phone': u'(415) 777-1077', u'address': u'46 Minna Street, San Francisco, CA 94105, USA', u'lat': u'37.7885627', u'type': u'Night Club'}
# {u'name': u'Lookout', u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=_bLCsw6PBLIAAAQfCRPoLQ&x=0&y=0&zoom=5', u'long': u'-122.4334227', u'hours': u'3:30 pm - 2:00 am', u'phone': u'(415) 431-0306', u'address': u'3600 16th Street, San Francisco, CA 94114, USA', u'lat': u'37.7643965', u'type': u'Gay Bar'}
# {u'name': u'Philosophers Club', u'image': u'https://lh3.googleusercontent.com/-8BbNqkpbUCE/Ug0zsuiPk6I/AAAAAAAALMM/VrQeyHnRlBk/s285-k-no/2013-08-15', u'long': u'-122.4654431', u'hours': u'10:00 am - 2:00 am', u'phone': u'(415) 753-0599', u'address': u'824 Ulloa Street, San Francisco, CA 94127, USA', u'lat': u'37.7408498', u'type': u'Bar'}
# {u'name': u'AsiaSF', u'image': u'http://asiasf.com/wp-content/uploads/2013/08/aliyah-amber-nya.jpg', u'long': u'-122.4127649', u'hours': u'7:15 pm - 2:00 am', u'phone': u'(415) 255-2742', u'address': u'201 9th Street, San Francisco, CA 94103, USA', u'lat': u'37.7750644', u'type': u'Asian Fusion Restaurant / Nigh Club'}
# {u'name': u'Delirium', u'image': u'https://lh6.googleusercontent.com/-vl37m4n-8xM/Uae7wVLdyUI/AAAAAAAAE8M/4pJRXEK7LyY/s285-k-no/2013-05-30', u'long': u'-122.4228718', u'hours': u'-2:00 pm - 2:00 am', u'phone': u'(415) 552-5525', u'address': u'3139 16th Street, San Francisco, CA 94103, USA', u'lat': u'37.7648463', u'type': u'Cocktail Bar'}
# {u'name': u'23 Club', u'image': u'https://lh6.googleusercontent.com/-gVSVS9fv0TQ/VMiSwcGk6PI/AAAAAAAAAAc/CQjSSlNB3CE/s286-k-no/photo.jpg', u'long': u'-122.4024009', u'hours': u'3pm - 2 am', u'phone': u'(415) 467-7717', u'address': u'23 Visitacion Avenue, Brisbane, CA 94005, USA', u'lat': u'37.6841542', u'type': u'Bar'}

# %%
data = urltoys.get_dict(urltoys.make_url(ip = ip))
data
# Out:
# {u'places': [{u'_id': u'5508deebd1e26e3536ceb8c5',
#    u'address': u'2801 Leavenworth Street, San Francisco, CA 94133, USA',
#    u'cover': 0,
#    u'hours': u'4:00pm-8:00am',
#    u'image': u'http://www.theparlorsf.com/media/uploads/interior_pics/front_door_homepage_horizontal.jpg',
#    u'information': u'',
#    u'lat': u'37.8073431',
#    u'line': 0,
#    u'long': u'-122.4194274',
#    u'name': u'The Parlor',
#    u'phone': u'(415) 775-5110',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Lounge Bar And Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8c5'},
#   {u'_id': u'5508deebd1e26e3536ceb8c6',
#    u'address': u'540 Clement Street, San Francisco, CA 94118, USA',
#    u'cover': 0,
#    u'hours': u'12:00pm-2:00am',
#    u'image': u'http://thenoisebeneaththeapple.com/wp-content/uploads/2012/08/540-club.jpg',
#    u'information': u'',
#    u'lat': u'37.7830929',
#    u'line': 0,
#    u'long': u'-122.4651637',
#    u'name': u'540 Club',
#    u'phone': u'(415) 752-7276',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8c6'},
#   {u'_id': u'5508deebd1e26e3536ceb8c7',
#    u'address': u'500 Guerrero Street, San Francisco, CA 94110, USA',
#    u'cover': 0,
#    u'hours': u'11:00 am - 2:00 am',
#    u'image': u'http://500clubsf.com/yahoo_site_admin/assets/images/5sign.78232104_std.jpg',
#    u'information': u'',
#    u'lat': u'37.7630363',
#    u'line': 0,
#    u'long': u'-122.4241888',
#    u'name': u'The 500 Club',
#    u'phone': u'(415) 861-2500',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8c7'},
#   {u'_id': u'5508deebd1e26e3536ceb8c8',
#    u'address': u'1160 Polk Street, San Francisco, CA 94109, USA',
#    u'cover': 0,
#    u'hours': u'3:00 pm - 2:00 am',
#    u'image': u'https://cbks3.google.com/cbk?output=thumbnail&cb_client=maps_sv&thumb=2&panoid=YQxqYBXmPZaYHAK_HWg49w&yaw=334.6064863861733&w=333&h=79',
#    u'information': u'',
#    u'lat': u'37.7875296',
#    u'line': 0,
#    u'long': u'-122.419814',
#    u'name': u'Vertigo',
#    u'phone': u'(415) 674-1278',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8c8'},
#   {u'_id': u'5508deebd1e26e3536ceb8c9',
#    u'address': u'3286 22nd Street, San Francisco, CA 94110, USA',
#    u'cover': 0,
#    u'hours': u'5:00 pm---2:00 am',
#    u'image': u'https://s-media-cache-ak0.pinimg.com/originals/7d/9d/1e/7d9d1ec887289c49d1c536340c33b4e9.jpg',
#    u'information': u'',
#    u'lat': u'37.7553415',
#    u'line': 0,
#    u'long': u'-122.4206599',
#    u'name': u'Latin American Club',
#    u'phone': u'(415) 647-2732',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8c9'},
#   {u'_id': u'5508deebd1e26e3536ceb8ca',
#    u'address': u'4121 18th Street, San Francisco, CA 94114, USA',
#    u'cover': 0,
#    u'hours': u'-3:00 pm - 2:00 am',
#    u'image': u'http://s3-media2.fl.yelpcdn.com/bphoto/rCjnajLYPAQfsC-4SZ5LBA/l.jpg',
#    u'information': u'',
#    u'lat': u'37.7607493',
#    u'line': 0,
#    u'long': u'-122.4354615',
#    u'name': u'San Francisco Badlands',
#    u'phone': u'(415) 626-9320',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8ca'},
#   {u'_id': u'5508deebd1e26e3536ceb8cb',
#    u'address': u'1192 Folsom Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u'5:00 pm - 3:00 am',
#    u'image': u'https://lh3.googleusercontent.com/-v2LRG0dy-gE/VNVl8sPHTPI/AAAAAAAAABE/etCksJeJYnE/s242-k-no/photo.jpg',
#    u'information': u'',
#    u'lat': u'37.775307',
#    u'line': 0,
#    u'long': u'-122.4099488',
#    u'name': u'F8',
#    u'phone': u'(415) 857-1192',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Lounge',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8cb'},
#   {u'_id': u'5508deebd1e26e3536ceb8cc',
#    u'address': u'20 Yerba Buena Lane, San Francisco, CA 94130, USA',
#    u'cover': 0,
#    u'hours': u'2:00 pm - 12:00 am',
#    u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=uRz9MR8A2rYAAAQY7sOC2A&x=0&y=0&zoom=5',
#    u'information': u'',
#    u'lat': u'37.7859785',
#    u'line': 0,
#    u'long': u'-122.4045719',
#    u'name': u'Press Club',
#    u'phone': u'(415) 744-5000',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Wine Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8cc'},
#   {u'_id': u'5508deebd1e26e3536ceb8cd',
#    u'address': u'3138 Fillmore Street, San Francisco, CA 94123, USA',
#    u'cover': 0,
#    u'hours': u'10pm-2am',
#    u'image': u'http://www.matrixfillmore.com/images/home_image_3.jpg',
#    u'information': u'',
#    u'lat': u'37.7986879',
#    u'line': 0,
#    u'long': u'-122.435665',
#    u'name': u'MatrixFillmore',
#    u'phone': u'(415) 563-4180',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8cd'},
#   {u'_id': u'5508deebd1e26e3536ceb8ce',
#    u'address': u'3225 22nd Street, San Francisco, CA 94110, USA',
#    u'cover': 0,
#    u'hours': u'6pm-2am',
#    u'image': u'http://danivox.com/wp-content/uploads/2012/12/DaniVox_MOR_8.jpg',
#    u'information': u'',
#    u'lat': u'37.7552647',
#    u'line': 0,
#    u'long': u'-122.4193588',
#    u'name': u'Make-Out Room',
#    u'phone': u'(415) 647-2888',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8ce'},
#   {u'_id': u'5508deebd1e26e3536ceb8cf',
#    u'address': u'1015 Folsom Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u' 10:00 pm - 3:00 am',
#    u'image': u'http://guestlistspy.com/wp-content/uploads/2012/07/1015-folsom-guestlist.jpg',
#    u'information': u'',
#    u'lat': u'37.7781009',
#    u'line': 0,
#    u'long': u'-122.4057628',
#    u'name': u'1015 Folsom',
#    u'phone': u'(415) 431-1200',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8cf'},
#   {u'_id': u'5508deebd1e26e3536ceb8d0',
#    u'address': u'420 Mason Street, San Francisco, CA 94102, USA',
#    u'cover': 0,
#    u'hours': u'9pm-2am',
#    u'image': u'http://www.rubyskye.com/_images/RubySkye.jpg',
#    u'information': u'',
#    u'lat': u'37.7875918',
#    u'line': 0,
#    u'long': u'-122.4098052',
#    u'name': u'Ruby Skye',
#    u'phone': u'(415) 693-0777',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d0'},
#   {u'_id': u'5508deebd1e26e3536ceb8d1',
#    u'address': u'853 Valencia Street, San Francisco, CA 94110, USA',
#    u'cover': 0,
#    u'hours': u'5:00 pm - 2:00 am',
#    u'image': u'http://uplup.com/music_spot/amnesia-san-francisco/additional_images/Amnesia%20bar.jpg',
#    u'information': u'',
#    u'lat': u'37.759309',
#    u'line': 0,
#    u'long': u'-122.4210613',
#    u'name': u'Amnesia',
#    u'phone': u'(415) 970-0012',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d1'},
#   {u'_id': u'5508deebd1e26e3536ceb8d2',
#    u'address': u'401 6th Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u' \nFriday 9:30 pm - 8:00 am\nSaturday 10:00 pm - 8:00 am\nSunday 1:00 - 9:00 pm \n',
#    u'image': u'http://www.theendup.com/club/wp-content/uploads/galleryimages/b7g76jET95e1icT8.jpg',
#    u'information': u'',
#    u'lat': u'37.7772436',
#    u'line': 0,
#    u'long': u'-122.4037707',
#    u'name': u'The Endup',
#    u'phone': u'(415) 646-0999',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d2'},
#   {u'_id': u'5508deebd1e26e3536ceb8d3',
#    u'address': u'43 6th Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u'7:00 pm - 2:00 am ',
#    u'image': u'https://evbdn.eventbrite.com/s3-s3/eventlogos/32513655/image2.png',
#    u'information': u'',
#    u'lat': u'37.7818047',
#    u'line': 0,
#    u'long': u'-122.4093351',
#    u'name': u'OMG!',
#    u'phone': u'(415) 896-6473',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d3'},
#   {u'_id': u'5508deebd1e26e3536ceb8d4',
#    u'address': u'375 11th Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u'Open 24 hours',
#    u'image': u'https://www.dnalounge.com/booking/005.jpg',
#    u'information': u'',
#    u'lat': u'37.7710189',
#    u'line': 0,
#    u'long': u'-122.412719',
#    u'name': u'DNA Lounge',
#    u'phone': u'(415) 626-1409',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d4'},
#   {u'_id': u'5508deebd1e26e3536ceb8d5',
#    u'address': u'124 Ellis Street, San Francisco, CA 94102, USA',
#    u'cover': 0,
#    u'hours': u'6:00 pm - 2:00 am',
#    u'image': u'http://guestlistamerica.com/wp-content/uploads/2013/02/main-lounge.jpg',
#    u'information': u'',
#    u'lat': u'37.7856002',
#    u'line': 0,
#    u'long': u'-122.4085226',
#    u'name': u'Infusion Lounge',
#    u'phone': u'(415) 421-8700',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Lounge',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d5'},
#   {u'_id': u'5508deebd1e26e3536ceb8d6',
#    u'address': u'540 Howard Street, San Francisco, CA 94105, USA',
#    u'cover': 0,
#    u'hours': u'10:00 pm - 4:00 am',
#    u'image': u'http://photos3.meetupstatic.com/photos/event/a/4/0/8/600_430061992.jpeg',
#    u'information': u'',
#    u'lat': u'37.7879165',
#    u'line': 0,
#    u'long': u'-122.3972358',
#    u'name': u'Temple Nightclub',
#    u'phone': u'(415) 978-9942',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d6'},
#   {u'_id': u'5508deebd1e26e3536ceb8d7',
#    u'address': u'46 Minna Street, San Francisco, CA 94105, USA',
#    u'cover': 0,
#    u'hours': u'9:00 pm - 2:00 am',
#    u'image': u'http://cdn.djoybeat.com/wp-content/uploads/2012/12/harlot-sf3.jpg',
#    u'information': u'',
#    u'lat': u'37.7885627',
#    u'line': 0,
#    u'long': u'-122.3982112',
#    u'name': u'Harlot',
#    u'phone': u'(415) 777-1077',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Night Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d7'},
#   {u'_id': u'5508deebd1e26e3536ceb8d8',
#    u'address': u'3600 16th Street, San Francisco, CA 94114, USA',
#    u'cover': 0,
#    u'hours': u'3:30 pm - 2:00 am',
#    u'image': u'https://geo0.ggpht.com/cbk?output=tile&cb_client=maps_sv.gps&panoid=_bLCsw6PBLIAAAQfCRPoLQ&x=0&y=0&zoom=5',
#    u'information': u'',
#    u'lat': u'37.7643965',
#    u'line': 0,
#    u'long': u'-122.4334227',
#    u'name': u'Lookout',
#    u'phone': u'(415) 431-0306',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Gay Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d8'},
#   {u'_id': u'5508deebd1e26e3536ceb8d9',
#    u'address': u'824 Ulloa Street, San Francisco, CA 94127, USA',
#    u'cover': 0,
#    u'hours': u'10:00 am - 2:00 am',
#    u'image': u'https://lh3.googleusercontent.com/-8BbNqkpbUCE/Ug0zsuiPk6I/AAAAAAAALMM/VrQeyHnRlBk/s285-k-no/2013-08-15',
#    u'information': u'',
#    u'lat': u'37.7408498',
#    u'line': 0,
#    u'long': u'-122.4654431',
#    u'name': u'Philosophers Club',
#    u'phone': u'(415) 753-0599',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8d9'},
#   {u'_id': u'5508deebd1e26e3536ceb8da',
#    u'address': u'201 9th Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u'7:15 pm - 2:00 am',
#    u'image': u'http://asiasf.com/wp-content/uploads/2013/08/aliyah-amber-nya.jpg',
#    u'information': u'',
#    u'lat': u'37.7750644',
#    u'line': 0,
#    u'long': u'-122.4127649',
#    u'name': u'AsiaSF',
#    u'phone': u'(415) 255-2742',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Asian Fusion Restaurant / Nigh Club',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8da'},
#   {u'_id': u'5508deebd1e26e3536ceb8db',
#    u'address': u'3139 16th Street, San Francisco, CA 94103, USA',
#    u'cover': 0,
#    u'hours': u'-2:00 pm - 2:00 am',
#    u'image': u'https://lh6.googleusercontent.com/-vl37m4n-8xM/Uae7wVLdyUI/AAAAAAAAE8M/4pJRXEK7LyY/s285-k-no/2013-05-30',
#    u'information': u'',
#    u'lat': u'37.7648463',
#    u'line': 0,
#    u'long': u'-122.4228718',
#    u'name': u'Delirium',
#    u'phone': u'(415) 552-5525',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Cocktail Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8db'},
#   {u'_id': u'5508deebd1e26e3536ceb8dc',
#    u'address': u'23 Visitacion Avenue, Brisbane, CA 94005, USA',
#    u'cover': 0,
#    u'hours': u'3pm - 2 am',
#    u'image': u'https://lh6.googleusercontent.com/-gVSVS9fv0TQ/VMiSwcGk6PI/AAAAAAAAAAc/CQjSSlNB3CE/s286-k-no/photo.jpg',
#    u'information': u'',
#    u'lat': u'37.6841542',
#    u'line': 0,
#    u'long': u'-122.4024009',
#    u'name': u'23 Club',
#    u'phone': u'(415) 467-7717',
#    u'pop': 0,
#    u'time_post_cover': 0,
#    u'time_post_line': 0,
#    u'type': u'Bar',
#    u'uri': u'/api/v1.0/places/5508deebd1e26e3536ceb8dc'}]}
